# %%
import pandas as pd
import sqlite3
import random
from datetime import datetime
import numpy as np

# %%
input_file=pd.read_csv("C:\Users\Divyakumar\Documents\GitHub\Mind-Heart-Reader\sensor_data\HMJ\Results-HMJ-18-Oct-2014-00-24-17.csv",index_col=None)
start_timestamp="18-Oct-2014 00:24:17" # Put the date in the right format
total_experiment_time_seconds = 1200  # Put the total number of lines in CSV file generated

# %%
rng = pd.date_range(pd.Timestamp('10/18/2014 00:24:17'), periods=1200, freq='S')
print rng
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-10-18 00:24:17, ..., 2014-10-18 00:44:16]
# Length: 1200, Freq: S, Timezone: None

# %%
input_file['StartDateTime']=pd.to_datetime(pd.Timestamp(start_timestamp))
input_file['RefDateTime']=pd.to_datetime(rng)
input_file
# Out:
#     Attention  Meditation  Familiarity  MentalEffort  Appreciation  \
# 0          30          61    14.089371      0.880674             1
# 1          16          67    17.885041      0.344428             1
# 2          41          88     2.808908     -1.261146             1
# 3          38          80     6.250109      1.333252             1
# 4          21          74     6.687963      1.289921             2
# 5          27          77     2.731921      0.707676             4
# 6          20          74     5.798418     -4.522141             4
# 7          24          75   -12.465059      1.124905             4
# 8          38          80     5.900887      1.844491             3
# 9          21          77     3.118239      2.141987             4
# 10         27          74   -13.726990     -2.367585             4
# 11         43          67     0.916590      2.186144             4
# 12         50          61    -3.975732      1.316770             4
# ...

# %%
rng = pd.date_range('10/18/2014 00:24:17', periods=120, freq='S')
print rng
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-10-18 00:24:17, ..., 2014-10-18 00:44:16]
# Length: 1200, Freq: S, Timezone: None

# %%
pd.to_datetime((input_file.index+1)*1000000000)
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [1970-01-01 00:00:01, ..., 1970-01-01 00:20:00]
# Length: 1200, Freq: None, Timezone: None

# %%
con = sqlite3.connect("..//Mind-Heart-Reader.db")
df = pd.read_sql("SELECT * from MHREADER_EXPERIMENTS LIMIT 3" ,con, index_col='id')
df
# Out:
#      title  user_id  experiment_set_id remarks start_time end_time completed
# id
# 1    Test1        1                  1               None     None      None
# 2   test 3        1                  3               None     None      None
#
# [2 rows x 7 columns]

# %%
import pandas as pd
import sqlite3
import random
from datetime import datetime
import numpy as np
from pandasql import *
pysqldf = lambda q: sqldf(q, globals())

# %%
input_file=pd.read_csv("C:\Users\Divyakumar\Documents\GitHub\Mind-Heart-Reader\sensor_data\HMJ2\Results-HMJ2-18-Oct-2014-14-52-53.csv",index_col=False)
start_timestamp="18-Oct-2014 14:52:53" # Put the date in the right format
total_experiment_time_seconds = len(input_file)
input_file.head()
# Out:
#    Attention  Meditation   Familiarity  MentalEffort  Appreciation  \
# 0         50          84    308.488527      0.482618             1
# 1         41          90   -791.783436     -2.101997             1
# 2         48          88 -19007.719304     -0.104035             1
# 3         47          80  -1679.220297      0.500986             1
# 4         40          91    460.087037      0.741878             2
#
#    SignalQuality  EventTagging     Delta     Theta     Alpha      Beta  \
# 0              1            -1  0.829160  1.744469  1.297991  0.858973
# 1              1            -1  1.366320  3.427371  2.387856  0.850816
# 2              1            -1  1.917496  4.716986  2.748253  0.617703
# 3              1            -1  1.728436  5.153085  2.481608  0.731716
# 4              1            -1  1.558926  1.450830  1.056220  0.474555
#
#       Gamma
# 0  0.104634
# 1  0.091614
# 2  0.129799
# 3  0.144616
# 4  0.081053
#
# [5 rows x 12 columns]

# %%
rng = pd.date_range(pd.Timestamp(start_timestamp), periods=total_experiment_time_seconds, freq='S')-total_experiment_time_seconds
print rng
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-10-18 14:42:55, ..., 2014-10-18 14:52:52]
# Length: 598, Freq: S, Timezone: None

# %%
input_file['EndDateTime']=pd.to_datetime(pd.Timestamp(start_timestamp))
input_file['RefDateTime']=pd.to_datetime(rng)
input_file.head(5)
# Out:
#    Attention  Meditation   Familiarity  MentalEffort  Appreciation  \
# 0         50          84    308.488527      0.482618             1
# 1         41          90   -791.783436     -2.101997             1
# 2         48          88 -19007.719304     -0.104035             1
# 3         47          80  -1679.220297      0.500986             1
# 4         40          91    460.087037      0.741878             2
#
#    SignalQuality  EventTagging     Delta     Theta     Alpha      Beta  \
# 0              1            -1  0.829160  1.744469  1.297991  0.858973
# 1              1            -1  1.366320  3.427371  2.387856  0.850816
# 2              1            -1  1.917496  4.716986  2.748253  0.617703
# 3              1            -1  1.728436  5.153085  2.481608  0.731716
# 4              1            -1  1.558926  1.450830  1.056220  0.474555
#
#       Gamma         EndDateTime         RefDateTime
# 0  0.104634 2014-10-18 14:52:53 2014-10-18 14:42:55
# 1  0.091614 2014-10-18 14:52:53 2014-10-18 14:42:56
# 2  0.129799 2014-10-18 14:52:53 2014-10-18 14:42:57
# 3  0.144616 2014-10-18 14:52:53 2014-10-18 14:42:58
# 4  0.081053 2014-10-18 14:52:53 2014-10-18 14:42:59
#
# [5 rows x 14 columns]

# %%
con = sqlite3.connect("C:\Users\Divyakumar\Documents\GitHub\Mind-Heart-Reader_1018\Mind-Heart-Reader.db")
df = pd.read_sql("SELECT id,user_id,experiment_id,timestamp,datetime(timestamp,'localtime') as localtime,action_type,experiment_file_id,result FROM mhreader_experiment_logs where experiment_id=4;" ,con, index_col='id')
df
# Out:
#      user_id  experiment_id                   timestamp            localtime  \
# id
# 96         2              4  2014-10-18 21:44:00.206792  2014-10-18 14:44:00
# 97         2              4  2014-10-18 21:44:22.263745  2014-10-18 14:44:22
# 98         2              4  2014-10-18 21:44:51.346456  2014-10-18 14:44:51
# 99         2              4  2014-10-18 21:45:13.082462  2014-10-18 14:45:13
# 100        2              4  2014-10-18 21:45:36.406777  2014-10-18 14:45:36
# 101        2              4  2014-10-18 21:45:57.956169  2014-10-18 14:45:57
# 102        2              4  2014-10-18 21:46:19.514441  2014-10-18 14:46:19
# 103        2              4  2014-10-18 21:46:41.148926  2014-10-18 14:46:41
# 104        2              4  2014-10-18 21:47:04.845615  2014-10-18 14:47:04
# 105        2              4  2014-10-18 21:47:27.041873  2014-10-18 14:47:27
# 106        2              4  2014-10-18 21:47:50.596350  2014-10-18 14:47:50
# 107        2              4  2014-10-18 21:48:13.928520  2014-10-18 14:48:13
# 108        2              4  2014-10-18 21:48:38.701373  2014-10-18 14:48:38
# 109        2              4  2014-10-18 21:49:00.655019  2014-10-18 14:49:00
# 110        2              4  2014-10-18 21:49:22.202064  2014-10-18 14:49:22
# 111        2              4  2014-10-18 21:49:44.174847  2014-10-18 14:49:44
# 112        2              4  2014-10-18 21:50:05.960563  2014-10-18 14:50:05
# 113        2              4  2014-10-18 21:50:27.528942  2014-10-18 14:50:27
# 114        2              4  2014-10-18 21:50:49.192318  2014-10-18 14:50:49
# 115        2              4  2014-10-18 21:51:10.821864  2014-10-18 14:51:10
# 116        2              4  2014-10-18 21:51:14.041118  2014-10-18 14:51:14
# 117        2              4  2014-10-18 21:51:16.628203  2014-10-18 14:51:16
# 118        2              4  2014-10-18 21:51:20.728061  2014-10-18 14:51:20
# 119        2              4  2014-10-18 21:51:31.329260  2014-10-18 14:51:31
# 120        2              4  2014-10-18 21:51:31.504043  2014-10-18 14:51:31
# 121        2              4  2014-10-18 21:51:31.674655  2014-10-18 14:51:31
# 122        2              4  2014-10-18 21:51:33.028839  2014-10-18 14:51:33
# 123        2              4  2014-10-18 21:52:38.245267  2014-10-18 14:52:38
#
#     action_type  experiment_file_id result
# id
# 96        click                  80   None
# 97        click                 636   None
# 98        click                 164   None
# 99        click                 140   None
# 100       click                 131   None
# 101       click                 169   None
# 102       click                 145   None
# 103       click                 211   None
# 104       click                 640   None
# 105       click                 171   None
# 106       click                 147   None
# 107       click                 251   None
# 108       click                 172   None
# 109       click                 358   None
# 110       click                 914   None
# 111       click                 446   None
# 112       click                 181   None
# 113       click                 363   None
# 114       click                 447   None
# 115       click                 182   None
# 116       click                 182   None
# 117       click                 182   None
# 118       click                 182   None
# 119       click                 182   None
# 120       click                 182   None
# 121       click                 182   None
# 122       click                 182   None
# 123       click                 182   None
#
# [28 rows x 7 columns]

# %%
for count, row in df.iterrows():
    print row[2]
# Out:
# 2014-10-18 21:44:00.206792
# 2014-10-18 21:44:22.263745
# 2014-10-18 21:44:51.346456
# 2014-10-18 21:45:13.082462
# 2014-10-18 21:45:36.406777
# 2014-10-18 21:45:57.956169
# 2014-10-18 21:46:19.514441
# 2014-10-18 21:46:41.148926
# 2014-10-18 21:47:04.845615
# 2014-10-18 21:47:27.041873
# 2014-10-18 21:47:50.596350
# 2014-10-18 21:48:13.928520
# 2014-10-18 21:48:38.701373
# 2014-10-18 21:49:00.655019
# 2014-10-18 21:49:22.202064
# 2014-10-18 21:49:44.174847
# 2014-10-18 21:50:05.960563
# 2014-10-18 21:50:27.528942
# 2014-10-18 21:50:49.192318
# 2014-10-18 21:51:10.821864
# 2014-10-18 21:51:14.041118
# 2014-10-18 21:51:16.628203
# 2014-10-18 21:51:20.728061
# 2014-10-18 21:51:31.329260
# 2014-10-18 21:51:31.504043
# 2014-10-18 21:51:31.674655
# 2014-10-18 21:51:33.028839
# 2014-10-18 21:52:38.245267

# %%
q = """
    SELECT
        *
    FROM
        input_file
    LIMIT 10;"""

print sqldf(q, locals())
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-43-317a8c5317d3> in <module>()
#       6     LIMIT 10;"""
#       7
# ----> 8 print sqldf(q, locals())
#
# C:\Anaconda\lib\site-packages\pandasql\sqldf.pyc in sqldf(q, env, inmemory)
#     113         df = env[table]
#     114         df = _ensure_data_frame(df, table)
# --> 115         _write_table(table, df, conn)
#     116
#     117     try:
#
# C:\Anaconda\lib\site-packages\pandasql\sqldf.pyc in _write_table(tablename, df, conn)
#      68             raise Exception(msg)
#      69
# ---> 70     write_frame(df, name=tablename, con=conn, flavor='sqlite')
#      71
#      72
#
# C:\Anaconda\lib\site-packages\pandas\io\sql.pyc in write_frame(frame, name, con, flavor, if_exists, **kwargs)
#     236     if func is None:
#     237         raise NotImplementedError
# --> 238     func(frame, name, safe_names, cur)
#     239     cur.close()
#     240     con.commit()
#
# C:\Anaconda\lib\site-packages\pandas\io\sql.pyc in _write_sqlite(frame, table, names, cur)
#     252     else:
#     253         data = [tuple(x) for x in frame.values.tolist()]
# --> 254     cur.executemany(insert_query, data)
#     255
#     256
#
# InterfaceError: Error binding parameter 12 - probably unsupported type.
